# %% [markdown]
# # Prueba Unidad 2
#
# 1. Utilice el metodo de la bisecci\'on para encontrar los ceros de la funcion $f(x)=x-3^{-x}$ definida en el intervalo $[0 ,1]$. Encontrar el numero de iteraciones $n$ requerido para encontrar un error $\varepsilon < 10^-5$ mediante el criterio $| f(x_n) |<\varepsilon$

# %%
using Plots 

f(x)=x-3^-x

x=0.0:0.1:1.0
y=f.(x)

plot(x,y)

# %%
using Roots

tracker = Roots.Tracks()
x0=find_zero(f,(0.0,1.0), Bisection(),tracks=tracker,atol=1e-5)
# Out:
# 0.5478053092956543

# %%
tracker
# Out:
# Results of univariate zero finding:
#
# * Converged to: 0.5478053092956543
# * Algorithm: Bisection()
# * iterations: 19
# * function evaluations ≈ 22
# * stopped as |f(x_n)| ≤ max(δ, |x|⋅ϵ) using δ = atol, ϵ = rtol
#
# Trace:
# (a₀, b₀) = ( 1.118751109680031e-154, 1 )
# (a₁, b₁) = ( 1.0795210693868056e-77, 1 )
# (a₂, b₂) = ( 3.3060778616876836e-39, 1 )
# (a₃, b₃) = ( 5.7598240413292423e-20, 1 )
# (a₄, b₄) = ( 2.4010660126805305e-10, 1 )
# (a₅, b₅) = ( 1.5497207641601562e-05, 1 )
# (a₆, b₆) = ( 0.003936767578125, 1 )
# (a₇, b₇) = ( 0.062744140625, 1 )
# (a₈, b₈) = ( 0.25048828125, 1 )
# (a₉, b₉) = ( 0.50048828125, 1 )
# (a₁₀, b₁₀) = ( 0.50048828125, 0.750244140625 )
# (a₁₁, b₁₁) = ( 0.50048828125, 0.6253662109375 )
# (a₁₂, b₁₂) = ( 0.50048828125, 0.56292724609375 )
# (a₁₃, b₁₃) = ( 0.531707763671875, 0.56292724609375 )
# (a₁₄, b₁₄) = ( 0.5473175048828125, 0.56292724609375 )
# (a₁₅, b₁₅) = ( 0.5473175048828125, 0.55512237548828125 )
# (a₁₆, b₁₆) = ( 0.5473175048828125, 0.55121994018554688 )
# (a₁₇, b₁₇) = ( 0.5473175048828125, 0.54926872253417969 )
# (a₁₈, b₁₈) = ( 0.5473175048828125, 0.54829311370849609 )
# (a₁₉, b₁₉) = ( 0.5478053092956543, 0.54829311370849609 )

# %% [markdown]
# 2. Utilice el metodo de la bisecci\'on para encontrar los ceros de la funcion $f(x)=e^x-x^2+2x-3$ definida en el intervalo $[0,2]$. Encontrar el numero de iteraciones $n$ requerido para encontrar un error $\varepsilon < 10^-5$ mediante el criterio $| f(x_n) - f(x_{n-1}) |< \varepsilon$

# %%
tracker = Roots.Tracks()

f(x)=exp(x)-x^2+2x-3

x0=find_zero(f,(0.0,2.0), Bisection(),tracks=tracker,xatol=1e-5)
# Out:
# 0.7291641235351562

# %%
tracker
# Out:
# Results of univariate zero finding:
#
# * Converged to: 0.7291641235351562
# * Algorithm: Bisection()
# * iterations: 25
# * function evaluations ≈ 28
# * stopped as x_n ≈ x_{n-1} using atol=xatol, rtol=xrtol
#
# Trace:
# (a₀, b₀) = ( 1.4916681462400413e-154, 2 )
# (a₁, b₁) = ( 1.7272337110188889e-77, 2 )
# (a₂, b₂) = ( 5.8774717541114375e-39, 2 )
# (a₃, b₃) = ( 1.0842021724855044e-19, 2 )
# (a₄, b₄) = ( 4.6566128730773926e-10, 2 )
# (a₅, b₅) = ( 3.0517578125e-05, 2 )
# (a₆, b₆) = ( 0.0078125, 2 )
# (a₇, b₇) = ( 0.125, 2 )
# (a₈, b₈) = ( 0.5, 2 )
# (a₉, b₉) = ( 0.5, 1 )
# (a₁₀, b₁₀) = ( 0.5, 0.75 )
# (a₁₁, b₁₁) = ( 0.625, 0.75 )
# (a₁₂, b₁₂) = ( 0.6875, 0.75 )
# (a₁₃, b₁₃) = ( 0.71875, 0.75 )
# (a₁₄, b₁₄) = ( 0.71875, 0.734375 )
# (a₁₅, b₁₅) = ( 0.7265625, 0.734375 )
# (a₁₆, b₁₆) = ( 0.7265625, 0.73046875 )
# (a₁₇, b₁₇) = ( 0.728515625, 0.73046875 )
# (a₁₈, b₁₈) = ( 0.728515625, 0.7294921875 )
# (a₁₉, b₁₉) = ( 0.72900390625, 0.7294921875 )
# (a₂₀, b₂₀) = ( 0.72900390625, 0.729248046875 )
# (a₂₁, b₂₁) = ( 0.7291259765625, 0.729248046875 )
# (a₂₂, b₂₂) = ( 0.7291259765625, 0.72918701171875 )
# (a₂₃, b₂₃) = ( 0.729156494140625, 0.72918701171875 )
# (a₂₄, b₂₄) = ( 0.729156494140625, 0.7291717529296875 )
# (a₂₅, b₂₅) = ( 0.72916412353515625, 0.7291717529296875 )

# %% [markdown]
# 3. Encuentre el intervalo $[a,b]$ para el cual se cumple el teorema del valor intermedio para la funci\'on $f(x)=x- \text{cos}\,x$

# %%
f(x)=x-cos(x)

x=0.0:0.1:1.0

y=f.(x)

plot(x,y)

f(0.8)*f(0.7)
# Out:
# -0.006697762897742214

# %% [markdown]
# 4. Utilice el metodo de Newton-Raphson para encontrar los ceros de la funci\'on $f(x)=x^3-5x^2+5$ definida en el intervalo $[-2 ,2]$. Encontrar el n\'umero de ceros y la cantidad de iteraciones $n$ requeridas para encontrar un error $\varepsilon < 10^-6$ mediante el criterio $| f(x_n) |<\varepsilon$

# %%
tracker = Roots.Tracks()

f(x)=x^3-5x^2+5
df(x)=3x^2-10x

x=-2.0:0.1:2.0

y=f.(x)

plot(x,y)

# %%
x0=find_zero((f,df),-1.0, Roots.Newton(),tracks=tracker,atol=1e-6)
# Out:
# -0.9190889976648845

# %%
tracker
# Out:
# Results of univariate zero finding:
#
# * Converged to: -0.9190889976648845
# * Algorithm: Roots.Newton()
# * iterations: 3
# * function evaluations ≈ 6
# * stopped as |f(x_n)| ≤ max(δ, |x|⋅ϵ) using δ = atol, ϵ = rtol
#
# Trace:
# x₁ = -1,	 fx₁ = -1
# x₂ = -0.92307692307692313,	 fx₂ = -0.04688211197087
# x₃ = -0.91909947482236642,	 fx₃ = -0.00012284704226850351
# x₄ = -0.9190889976648845,	 fx₄ = -8.5152329631910106e-10

# %% [markdown]
# 5. Utilice el metodo de la secante para encontrar los ceros de la funcion $ff(x)=\text{ln}\,x+2 \text{cos} \, x-7$ definida en el intervalo $[2,3]$. Encontrar el n\'umero de iteraciones $n$ requerido para encontrar un error $\varepsilon < 10^-6$ mediante el criterio $| f(x_n - x_{n-1}) |< \varepsilon$

# %%
tracker = Roots.Tracks()

f(x)=log(x)+2*cos(x)

x=0.1:0.1:3.0

y=f.(x)

x0=find_zero(f,2.0, Roots.Secant(),tracks=tracker,xatol=1e-6)
# Out:
# 1.8965431395662975

# %%
plot(x,y)

# %%
tracker
# Out:
# Results of univariate zero finding:
#
# * Converged to: 1.8965431395662975
# * Algorithm: Secant()
# * iterations: 4
# * function evaluations ≈ 6
# * stopped as x_n ≈ x_{n-1} using atol=xatol, rtol=xrtol
#
# Trace:
# x₁ = 2.0000060555277894,	 fx₁ = -0.13915447731144248
# x₂ = 2,	 fx₂ = -0.13914649253433953
# x₃ = 1.8944735161071162,	 fx₃ = 0.0028310833298571536
# x₄ = 1.8965777517062177,	 fx₄ = -4.7333576353225659e-05
# x₅ = 1.8965431490063167,	 fx₅ = -1.2909628477331125e-08
# x₆ = 1.8965431395662975,	 fx₆ = 5.9285909514983359e-14
